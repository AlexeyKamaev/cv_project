# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)
# Out:
# Fri Mar  1 07:07:56 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   40C    P8               9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %%
# !pip install -q kaggle

from google.colab import files

files.upload()
# Out:
#      <input type="file" id="files-4f9cd153-f5da-4021-a8cb-719a9c1f0e03" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4f9cd153-f5da-4021-a8cb-719a9c1f0e03">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !mkdir ~/.kaggle

# !cp kaggle.json ~/.kaggle/

# %%
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets list
# Out:
# ...
# ref                                                     title                                          size  lastUpdated          downloadCount  voteCount  usabilityRating
# ------------------------------------------------------  --------------------------------------------  -----  -------------------  -------------  ---------  ---------------
# syedanwarafridi/vehicle-sales-data                      Vehicle Sales Data                             19MB  2024-02-21 20:16:17           4379         73  1.0
# nelgiriyewithana/apple-quality                          Apple Quality                                 170KB  2024-01-11 14:31:07          23917        518  1.0
# kanchana1990/spotifys-long-hits-2014-2024               Spotify's Long Hits (2014-2024) 🎶              38KB  2024-02-23 12:39:02           1669         43  1.0
# ...

# %%
# !kaggle datasets download -d kylegraupe/wind-turbine-image-dataset-for-computer-vision
# Out:
# ...
#  99% 609M/617M [00:08<00:00, 89.4MB/s]
# 100% 617M/617M [00:08<00:00, 73.0MB/s]

# %%
# !unzip wind-turbine-image-dataset-for-computer-vision.zip -d dataset_folder
# Out:
# Выходные данные были обрезаны до нескольких последних строк (5000).
#   inflating: dataset_folder/train/images/windmill38_jpg.rf.18ca44b93a71069515473052727878fd.jpg
#   inflating: dataset_folder/train/images/windmill38_jpg.rf.2177f1a5c403ad423103042546fd177f.jpg
#   inflating: dataset_folder/train/images/windmill38_jpg.rf.2b1a4bbcd4fd8c7ef63a0b0704b9894f.jpg
#   inflating: dataset_folder/train/images/windmill38_jpg.rf.2df1c417aba8fc4efae6bee731484943.jpg
#   inflating: dataset_folder/train/images/windmill38_jpg.rf.57a70129e462bceb5096604fb4fb0cac.jpg
#   inflating: dataset_folder/train/images/windmill38_jpg.rf.59bf2c49243c836a211d2ce80f55fb40.jpg
#   inflating: dataset_folder/train/images/windmill38_jpg.rf.75cb92200f5a421938230203103d8739.jpg
#   inflating: dataset_folder/train/images/windmill38_jpg.rf.82e54312624825140e91e44193899bc9.jpg
#   inflating: dataset_folder/train/images/windmill38_jpg.rf.8f8f9214864bb6ff4fa2494790875ce4.jpg
# ...

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 716.3/716.3 kB 10.6 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO
import os
from IPython.display import display, Image
from IPython import display
display.clear_output()
 #!yolo mode=checks

# %%
# Create a new YOLO model from scratch
#model = YOLO('yolov8n.yaml')

# Load a pretrained YOLO model (recommended for training)
#model = YOLO('yolov8n.pt')

# Train the model using the 'coco128.yaml' dataset for 3 epochs
#results = model.train(data='coco128.yaml', epochs=3)

# Evaluate the model's performance on the validation set
#results = model.val()

# Perform object detection on an image using the model
#results = model('https://ultralytics.com/images/bus.jpg')

# Export the model to ONNX format
#success = model.export(format='onnx')

# %%
model = YOLO('yolov8n.yaml')

# %%
model = YOLO('yolov8n.pt')
# Out:
# ...
# 100%|██████████| 6.23M/6.23M [00:00<00:00, 119MB/s]

# %%
results = model.train(data='/content/dataset_folder/data.yaml', epochs=60)
# Out:
# Ultralytics YOLOv8.1.20 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
results = model.val()
# Out:
# Ultralytics YOLOv8.1.20 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# val: Scanning /content/dataset_folder/valid/labels.cache... 247 images, 1 backgrounds, 0 corrupt: 100%|██████████| 247/247 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 16/16 [00:11<00:00,  1.44it/s]
#                    all        247       1562      0.795      0.619      0.713      0.443
#            cable tower        247         24      0.814      0.458      0.579      0.302
#                turbine        247       1538      0.776      0.779      0.847      0.584
# Speed: 0.8ms preprocess, 6.5ms inference, 0.0ms loss, 4.1ms postprocess per image
# Results saved to runs/detect/train23

# %%
test_images_path = "/content/dataset_folder/test/images"
test_image_files = os.listdir(test_images_path)
image_extensions = [".jpg", ".jpeg", ".png"]
test_images = [file for file in test_image_files if any(file.lower().endswith(ext) for ext in image_extensions)]

num_test_images = len(test_images)
num_test_images
# Out:
# 130

# %%
train_images_path = "/content/dataset_folder/train/images"

train_image_files = os.listdir(train_images_path)

image_extensions = [".jpg", ".jpeg", ".png"]
train_images = [file for file in train_image_files if any(file.lower().endswith(ext) for ext in image_extensions)]

num_train_images = len(train_images)

num_train_images
# Out:
# Number of train images: 2643

# %%
valid_images_path = "/content/dataset_folder/valid/images"

valid_image_files = os.listdir(valid_images_path)

image_extensions = [".jpg", ".jpeg", ".png"]
valid_images = [file for file in valid_image_files if any(file.lower().endswith(ext) for ext in image_extensions)]

num_valid_images = len(valid_images)

num_valid_images
# Out:
# Number of valid images: 247

# %%
from google.colab import files

files.download("/content/runs/detect/train3/weights/best.pt")

# %%
result = model.predict("https://ultralytics.com/images/bus.jpg")
# Out:
# Found https://ultralytics.com/images/bus.jpg locally at bus.jpg
# image 1/1 /content/bus.jpg: 640x480 6 cable towers, 14.3ms
# Speed: 3.7ms preprocess, 14.3ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 480)

# %%
files.download("/content/runs/detect/train/weights/best.pt")
